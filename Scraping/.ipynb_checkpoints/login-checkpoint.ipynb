# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a9e7709aa8b7> in <module>
# ----> 1 from selenium import webdriver
#       2 from selenium.webdriver.chrome.service import Service
#       3 from selenium.webdriver.common.by import By
#
# ModuleNotFoundError: No module named 'selenium'

# %%
browser = webdriver.Chrome(service=Service("/Users/kii/lang/python/chromedriver"))
browser.get('https://scraping-for-beginner.herokuapp.com/login_page')

# %%
# 要素を指定
elem_username = browser.find_element(by=By.ID, value='username')

# %%
elem_username
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7e80ca33351327a6f652601efde45b8f", element="355a5cb1-3f1f-473b-8b15-708664d59d8b")>

# %%
elem_username.send_keys('imanishi')

# %%
elem_password = browser.find_element(by=By.ID, value='password')

# %%
elem_password.send_keys('kohei')

# %%
elem_login_btn = browser.find_element(by=By.ID, value='login-btn')

# %%
elem_login_btn.click()

# %%
elem = browser.find_element(by=By.ID, value='name')

# %%
elem.text
# Out:
# '今西 航平'

# %%
elem = browser.find_element(by=By.ID, value='company')

# %%
elem.text
# Out:
# '株式会社キカガク'

# %%
elem = browser.find_element(by=By.ID, value='birthday')

# %%
elem.text
# Out:
# '1994年7月15日'

# %%
elem = browser.find_element(by=By.ID, value='come_from')

# %%
elem.text
# Out:
# '千葉県'

# %%
elem = browser.find_element(by=By.ID, value='hobby')

# %%
hobby = elem.text
hobby
# Out:
# 'バスケットボール\n読書\nガジェット集め'

# %%
type(hobby)
# Out:
# str

# %%
hobby.replace('\n',',')
# Out:
# 'バスケットボール,読書,ガジェット集め'

# %%
elem_th = browser.find_element(by=By.TAG_NAME, value='th')

# %%
elem_th.text
# Out:
# '講師名'
